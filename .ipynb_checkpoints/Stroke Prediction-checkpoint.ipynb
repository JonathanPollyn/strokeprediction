# %% [markdown]
# ## Introduction

# %% [markdown]
# According to the World Health Organization (WHO), stroke is the second most prevalent cause of mortality worldwide, accounting for approximately 11% of all fatalities.
# The purpose of this notebook is to predict the likelihood of a patient experiencing a stroke based on input parameters such as gender, age, presence of various diseases, and smoking status. This project demonstrates the power of machine learning classification.
#
# Attribute Information
# - **id**: unique identifier**
# - **gender**: "Male", "Female" or "Other"
# - **age**: age of the patient
# - **hypertension**: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
# - **heart_disease**: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease
# - **ever_married**: "No" or "Yes"
# - **work_type**: "children", "Govt_jov", "Never_worked", "Private" or "Self-employed"
# - **Residence_type**: "Rural" or "Urban"
# - **avg_glucose_level**: average glucose level in blood
# - **bmi**: body mass index
# - **smoking_status**: "formerly smoked", "never smoked", "smokes" or "Unknown"*
# - **stroke**: 1 if the patient had a stroke or 0 if not
#
# Link to data: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import seaborn as sns

# %%
stroke_df = pd.read_csv('healthcare-dataset-stroke-data.csv')
stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
stroke_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# ## Data Preprocessing

# %%
# Checking for missing values
stroke_df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Handle the missing values on the bmi
stroke_df['bmi'] = stroke_df['bmi'].fillna(stroke_df['bmi'].mean())

# Checking for missing values
stroke_df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level        bmi  \
# 0        Private          Urban             228.69  36.600000
# 1  Self-employed          Rural             202.21  28.893237
# 2        Private          Rural             105.92  32.500000
# 3        Private          Urban             171.23  34.400000
# 4  Self-employed          Rural             174.12  24.000000
#
#     smoking_status  stroke
# 0  formerly smoked       1
# 1     never smoked       1
# 2     never smoked       1
# 3           smokes       1
# 4     never smoked       1

# %% [markdown]
# ## Exploratory Data Analysis (EDA) and Data Visualization

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
# Data Shape
stroke_df.shape
# Out:
# (5110, 12)

# %%
# Statistical Properties
stroke_df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.698018     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.400000     0.000000
# ...

# %%
stroke_df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
stroke_df['age'] = stroke_df['age'].astype('int')

# %%
stroke_df.head()
# Out:
#       id  gender  age  hypertension  heart_disease ever_married  \
# 0   9046    Male   67             0              1          Yes
# 1  51676  Female   61             0              0          Yes
# 2  31112    Male   80             0              1          Yes
# 3  60182  Female   49             0              0          Yes
# 4   1665  Female   79             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level        bmi  \
# 0        Private          Urban             228.69  36.600000
# 1  Self-employed          Rural             202.21  28.893237
# 2        Private          Rural             105.92  32.500000
# 3        Private          Urban             171.23  34.400000
# 4  Self-employed          Rural             174.12  24.000000
#
#     smoking_status  stroke
# 0  formerly smoked       1
# 1     never smoked       1
# 2     never smoked       1
# 3           smokes       1
# 4     never smoked       1

# %%
stroke_df['age'].min()
# Out:
# 0

# %%
# Filter the data to exclude a 0 age
#stroke_df = stroke_df[stroke_df['age'] > 0]

# %%
stroke_df.shape
# Out:
# (5110, 12)

# %%
stroke_df['id'].nunique()
# Out:
# 5110

# %%
stroke_df['stroke'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
stroke_df
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80             1              0          Yes
# 5106  44873  Female   81             0              0          Yes
# 5107  19723  Female   35             0              0          Yes
# 5108  37544    Male   51             0              0          Yes
# 5109  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %% [markdown]
# ### Visualization

# %%
# Create a contigency table for gender and target
crosstab_gs = pd.crosstab(stroke_df['gender'], stroke_df['stroke'])
crosstab_gs
# Out:
# stroke     0    1
# gender
# Female  2853  141
# Male    2007  108
# Other      1    0

# %%
# Create a contigency table for smoke status and target
crosstab_ss = pd.crosstab(stroke_df['smoking_status'], stroke_df['stroke'])
crosstab_ss
# Out:
# stroke              0   1
# smoking_status
# Unknown          1497  47
# formerly smoked   815  70
# never smoked     1802  90
# smokes            747  42

# %%
# create bar graph based on the table.
crosstab_gs.plot(kind='bar', stacked = True)
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
# create bar graph based on the table.
crosstab_ss.plot(kind='bar', stacked = True);

# %%
#  Separate variable to graph by overlay
st_age_y = stroke_df[stroke_df.stroke == 1]['age']
st_age_n = stroke_df[stroke_df.stroke == 0]['age']

# %%
plt.hist([st_age_y, st_age_n], bins = 10, stacked = True)
plt.legend(['Response = Yes', 'Response = No'])
plt.title('Histogram of Age with Response Overlay')
plt.xlabel('Age')
plt.ylabel('Frequency')
                              
plt.show()

# %%
stroke_df.hist(figsize=(15, 8))
plt.show()

# %%
stroke_df.head()
# Out:
#       id  gender  age  hypertension  heart_disease ever_married  \
# 0   9046    Male   67             0              1          Yes
# 1  51676  Female   61             0              0          Yes
# 2  31112    Male   80             0              1          Yes
# 3  60182  Female   49             0              0          Yes
# 4   1665  Female   79             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level        bmi  \
# 0        Private          Urban             228.69  36.600000
# 1  Self-employed          Rural             202.21  28.893237
# 2        Private          Rural             105.92  32.500000
# 3        Private          Urban             171.23  34.400000
# 4  Self-employed          Rural             174.12  24.000000
#
#     smoking_status  stroke
# 0  formerly smoked       1
# 1     never smoked       1
# 2     never smoked       1
# 3           smokes       1
# 4     never smoked       1

# %% [markdown]
# ## Feature Engineering and Encoding

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
# Define age bins and labels
bins = [0, 18, 35, 50, 65, 80, np.inf]
labels = ['0-18', '19-35', '36-50', '51-65', '66-80', '80+']

# Create age bracket column
stroke_df['age_bracket'] = pd.cut(stroke_df['age'], bins=bins, labels=labels, right=False)

# Display the DataFrame with the new age bracket column
stroke_df
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80             1              0          Yes
# 5106  44873  Female   81             0              0          Yes
# 5107  19723  Female   35             0              0          Yes
# 5108  37544    Male   51             0              0          Yes
# 5109  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
# Drop unneccessary Columns
X = stroke_df.drop(['stroke','id','age', 'ever_married','work_type', 'Residence_type'], axis=1)
y = stroke_df['stroke']

# %%
# Label encoding for categorical variables
label_encoders = {}
for column in ['gender','smoking_status', 'age_bracket']:
    le = LabelEncoder()
    X[column] = le.fit_transform(X[column])
    label_encoders[column] = le

# %%
label_encoders
# Out:
# {'gender': LabelEncoder(),
#  'smoking_status': LabelEncoder(),
#  'age_bracket': LabelEncoder()}

# %%
X.head()
# Out:
#    gender  hypertension  heart_disease  avg_glucose_level        bmi  \
# 0       1             0              1             228.69  36.600000
# 1       0             0              0             202.21  28.893237
# 2       1             0              1             105.92  32.500000
# 3       0             0              0             171.23  34.400000
# 4       0             1              0             174.12  24.000000
#
#    smoking_status  age_bracket
# 0               1            4
# 1               2            3
# 2               2            5
# 3               3            2
# 4               2            4

# %%
# Apply MinMaxScaler
scaler = MinMaxScaler()

# %%
X.columns
# Out:
# Index(['gender', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'age_bracket'],
#       dtype='object')

# %%
columns_to_scale = ['gender', 'hypertension', 'heart_disease', 'avg_glucose_level',  'bmi','smoking_status', 'age_bracket']

# %%
X[columns_to_scale] = scaler.fit_transform(X[columns_to_scale])
X
# Out:
#       gender  hypertension  heart_disease  avg_glucose_level       bmi  \
# 0        0.5           0.0            1.0           0.801265  0.301260
# 1        0.0           0.0            0.0           0.679023  0.212981
# 2        0.5           0.0            1.0           0.234512  0.254296
# 3        0.0           0.0            0.0           0.536008  0.276060
# 4        0.0           1.0            0.0           0.549349  0.156930
# ...      ...           ...            ...                ...       ...
# 5105     0.0           1.0            0.0           0.132167  0.212981
# 5106     0.0           0.0            0.0           0.323516  0.340206
# 5107     0.0           0.0            0.0           0.128658  0.232532
# 5108     0.5           0.0            0.0           0.513203  0.175258
# 5109     0.0           0.0            0.0           0.139230  0.182131
#
#       smoking_status  age_bracket
# 0           0.333333          0.8
# 1           0.666667          0.6
# ...

# %%
# Check class distribution
y.value_counts()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %% [markdown]
# There is a data imbalance as the target value for 1 is not up to 10% of the 0

# %%
# pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_reset, y_reset = smote.fit_resample(X, y)

# %% [markdown]
# ## Train | Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X_reset, y_reset, test_size=0.2, random_state=42)

# %%
print ('Training cases: %d\nTest cases: %d' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Training cases: 7777
# Test cases: 1945

# %% [markdown]
# ## Build and Train the Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix,ConfusionMatrixDisplay, precision_score, recall_score,roc_curve, roc_auc_score

# %%
# Initialize and train the model 
logreg = LogisticRegression() 
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions 
predictions = logreg.predict(X_test)

# %%
print('Accuracy: ', accuracy_score(y_test, predictions))
# Out:
# Accuracy:  0.781491002570694

# %% [markdown]
# ## Evaluate the Model

# %%
accuracy = accuracy_score(y_test, predictions)
print('Accuracy:', accuracy)
print("Classification Report:\n", classification_report(y_test, predictions))

conf_matrix = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
disp.plot()
plt.show()
# Out:
# Accuracy: 0.781491002570694
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.75      0.78       975
#            1       0.76      0.81      0.79       970
#
#     accuracy                           0.78      1945
#    macro avg       0.78      0.78      0.78      1945
# weighted avg       0.78      0.78      0.78      1945

# %% [markdown]
# Try another model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Initialize and train the model 
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Make predictions 
rfc_predictions = rfc.predict(X_test)

# %%
accuracy = accuracy_score(y_test, rfc_predictions)
print('Accuracy:', accuracy)
print("Classification Report:\n", classification_report(y_test, rfc_predictions))

conf_matrix = confusion_matrix(y_test, rfc_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
disp.plot()
plt.show()
# Out:
# Accuracy: 0.9259640102827763
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       975
#            1       0.92      0.94      0.93       970
#
#     accuracy                           0.93      1945
#    macro avg       0.93      0.93      0.93      1945
# weighted avg       0.93      0.93      0.93      1945

# %% [markdown]
# ## Save the model

# %%
import joblib
joblib.dump(rfc, 'stroke_prediction_model.pkl')

# Save the scalers and label encoders
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(label_encoders, 'label_encoders.pkl')
# Out:
# ['label_encoders.pkl']

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Load the model
model = joblib.load('stroke_prediction_model.pkl')

# Load the scalers and label encoders
scaler = joblib.load('scaler.pkl')
label_encoders = joblib.load('label_encoders.pkl')

# Sample new data for prediction
new_data = {
    'gender': ['Male'],
    'hypertension': [0],
    'heart_disease': [0],
    'avg_glucose_level': [105.92],
    'bmi': [32.50],
    'smoking_status': ['never smoked'],    
    'age_bracket': ['80+'],
}

# Create DataFrame
input_data = pd.DataFrame(new_data)

# Apply the same label encoding
for column, le in label_encoders.items():
    input_data[column] = le.transform(input_data[column])

# Apply the same MinMaxScaler
columns_to_scale = ['gender', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi', 'smoking_status', 'age_bracket']
input_data[columns_to_scale] = scaler.transform(input_data[columns_to_scale])

# Make predictions
prediction = model.predict(input_data)

print('Predicted label:', prediction[0])
# Out:
# Predicted label: 1

# %% [markdown]
# ## END
